# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("resultado.csv",header=None)
centroids = pd.read_csv("centroids.csv",header=None)

# %%
centroids.head()
# Out:
#           0         1
# 0 -0.029122 -1.353026
# 1 -0.683664  0.300289
# 2 -0.391533  1.242676
# 3 -1.419754 -0.622863
# 4  1.172676 -0.736030

# %%
plt.scatter(data[1], data[2], s=10, label=name, c = data[0]*10)
plt.scatter(centroids[0], centroids[1], s=20, c='red')

# %%
kmeans = KMeans(n_clusters = 15, init = 'random')

# %%
X = data.iloc[:, 1:3].values

# %%
X
# Out:
# array([[-0.36559109, -1.40427449],
#        [-0.33476062, -1.52580983],
#        [-0.27979181, -1.33390924],
#        ...,
#        [ 0.62808123, -0.57775102],
#        [ 0.46541232, -0.25414296],
#        [-0.02508553, -0.27830756]])

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#        n_clusters=15, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-1.53500009e+00,  2.68885187e-01],
#        [-1.10560479e+00,  1.49648691e+00],
#        [ 1.27983822e+00, -1.10157723e+00],
#        [ 1.40518640e+00,  2.03415499e-01],
#        [-2.26257885e-01, -1.53375832e+00],
#        [ 1.26280652e+00,  1.00160246e+00],
#        [-8.05069574e-01, -1.40671540e+00],
#        [-1.41975389e+00, -6.22863153e-01],
#        [-7.25550829e-01,  2.85988976e-01],
#        [-3.97347285e-01,  1.23936416e+00],
#        [ 4.25918618e-01, -4.06436889e-01],
#        [ 3.74847367e-01,  3.38134274e-01],
#        [-4.74779948e-01, -3.80702606e-01],
#        [-1.16776678e-03, -1.32281260e+00],
#        [ 6.39012671e-01,  1.55986225e+00]])

# %%
plt.scatter(X[:, 0], X[:,1], s = 10, c = kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 20, c = 'red',label = 'Centroids')
plt.title('Data Clusters and Centroids')
plt.xlabel('SepalLength')
plt.ylabel('SepalWidth')
plt.legend()

plt.show()
