# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("resultado.csv",header=None)

# %%
data.head()
# Out:
#    0       1       2
# 0  0  294275  174786
# 1  0  329428   66056
# 2  0  325938  164475
# 3  0  253129  154296
# 4  0  319838  170383

# %%
groups = data.groupby(0)
for name, group in groups:
    plt.plot(group[1], group[2], marker="o", linestyle="", label=name)
plt.legend()

# %%
kmeans = KMeans(n_clusters = 15, init = 'random')

# %%
X = data.iloc[:, 1:2].values

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#        n_clusters=15, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[495667.96753247],
#        [238534.8125    ],
#        [123380.16013072],
#        [883138.36466165],
#        [381675.33114754],
#        [630643.93962264],
#        [335690.72208437],
#        [419160.56532663],
#        [680565.59259259],
#        [599197.93559322],
#        [801994.8       ],
#        [174493.68733154],
#        [292064.69565217],
#        [548970.62091503],
#        [844700.58811881]])

# %%
plt.scatter(X[:, 0], X[:,1], s = 100, c = kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'red',label = 'Centroids')
plt.title('Data Clusters and Centroids')
plt.xlabel('SepalLength')
plt.ylabel('SepalWidth')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-c292fea0ed78> in <module>
# ----> 1 plt.scatter(X[:, 0], X[:,1], s = 100, c = kmeans.labels_)
#       2 plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'red',label = 'Centroids')
#       3 plt.title('Data Clusters and Centroids')
#       4 plt.xlabel('SepalLength')
#       5 plt.ylabel('SepalWidth')
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
