# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("resultado.csv",header=None)
centroids = pd.read_csv("centroids.csv",header=None)

# %%
centroids.head()
# Out:
#           0         1
# 0  0.437807  0.365960
# 1  0.473508 -1.455013
# 2 -1.519671 -0.458924
# 3 -1.200156  1.538417

# %%
groups = data.groupby(0)
for name, group in groups:
    plt.plot(group[2], group[3], marker="o", linestyle="", label=name)
plt.scatter(centroids[0], centroids[1], s = 200, c = 'red',label = 'Centroids')
plt.legend()

# %%
kmeans = KMeans(n_clusters = 4, init = 'random')

# %%
X = data.iloc[:, 2:4].values

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300, n_clusters=4,
#        n_init=10, n_jobs=None, precompute_distances='auto', random_state=None,
#        tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.6553777 ,  0.44614304],
#        [-0.55571166, -0.32842202],
#        [ 0.56244182, -1.51178532],
#        [-1.85631343,  1.14617399]])

# %%
plt.scatter(X[:, 0], X[:,1], s = 100, c = kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'red',label = 'Centroids')
plt.title('Data Clusters and Centroids')
plt.xlabel('SepalLength')
plt.ylabel('SepalWidth')
plt.legend()

plt.show()
